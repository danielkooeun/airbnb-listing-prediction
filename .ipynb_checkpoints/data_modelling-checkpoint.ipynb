# %%
import torch
import torch.utils.data
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import os
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

GPU = torch.cuda.is_available()

# %%
# Grab data from csv
df = pd.read_csv('aps360_airbnb2.csv', index_col=False)
df.head()
# Out:
#    Unnamed: 0  host_is_superhost  guests_included  bathrooms  bedrooms  \
# 0           0                  0         0.133333     0.1250  0.142857
# 1           1                  1         0.066667     0.1250  0.142857
# 2           2                  0         0.666667     0.5625  0.714286
# 3           3                  0         0.066667     0.1250  0.000000
# 4           4                  0         0.400000     0.2500  0.428571
#
#        beds     price  cleaning_fee  instant_bookable  ballard  \
# 0  0.000000  0.066327      0.000000                 0        0
# 1  0.000000  0.132653      0.133333                 0        0
# 2  0.428571  0.974490      1.000000                 0        0
# 3  0.071429  0.081633      0.000000                 0        0
# 4  0.142857  0.438776      0.416667                 0        0
#
#          ...          safety_card  shampoo  smoke_detector  smoking_allowed  \
# 0        ...                    0        0               0                0
# ...

# %%
# Cleaning Data
df_cols = list(df.columns)
df_cols.remove('price')
df_cols.remove('Unnamed: 0')
df_cols.append('price')
df = df[df_cols]

input_features = len(df_cols) - 1
print(input_features)
print(len(df))
# Out:
# 97
# 3793

# %%
# turn data into 
datanp = df.values.astype(np.float32)
np.random.seed(50) # set the numpy seed for consistent split

# Data split count (train/valid/test): 2276/758/759
train_set = np.random.choice(range(3793), 2276, replace=False)
train_set.sort()
valid_set = np.random.choice([i for i in range(3793) if i not in train_set], 758, replace=False)
valid_set.sort()
test_set = [i for i in range(3793) if i not in train_set and i not in valid_set]

train_set = datanp[train_set]
valid_set = datanp[valid_set]
test_set = datanp[test_set]

separator = torch.from_numpy(np.array(range(input_features)))

# %% [markdown]
# # Groups of Data
# - host_is_superhost
# - guests_included
# - bathrooms
# - bedrooms
# - beds
# - cleaning_fee
# - instant_bookable
#
# Residence Areas
# - ballard
# - beacon_hill
# - capitol_hill
# - cascade
# - central_area
# - delridge
# - downtown
# - interbay
# - lake_city
# - magnolia
# - northgate
# - other_neighborhoods
# - queen_anne
# - rainier_valley
# - seward_park
# - university_district
# - west_seattle
#
# AirBnB Type
# - Apartment
# - Bed & Breakfast
# - Boat
# - Bungalow
# - Cabin
# - Camper/RV
# - Chalet
# - Condominium
# - Dorm
# - House
# - Loft
# - Other
# - Tent
# - Townhouse
# - Treehouse
# - Yurt
#
# Living Style
# - Entire home/apt
# - Private room
# - Shared room
#
# Bed Type
# - Airbed
# - Couch
# - Futon
# - Pull-out Sofa
# - Real Bed
#
# Cancellation Policy
# - flexible
# - moderate
# - strict
#
# Location
# - location_x
# - location_y
# - location_z
#
# Ameneties
# - 24-hour_check-in
# - air_conditioning
# - breakfast
# - buzzer/wireless_intercom
# - cable_tv
# - carbon_monoxide_detector
# - cat(s)
# - dog(s)
# - doorman
# - dryer
# - elevator_in_building
# - essentials
# - family/kid_friendly
# - fire_extinguisher
# - first_aid_kit
# - free_parking_on_premises
# - gym
# - hair_dryer
# - hangers
# - heating
# - hot_tub
# - indoor_fireplace
# - internet
# - iron
# - kitchen
# - laptop_friendly_workspace
# - lock_on_bedroom_door
# - other_pet(s)
# - pets_allowed
# - pets_live_on_this_property
# - pool
# - safety_card
# - shampoo
# - smoke_detector
# - smoking_allowed
# - suitable_for_events
# - tv
# - washer
# - washer_/_dryer
# - wheelchair_accessible
# - wireless_internet

# %%
corr = df.corr().loc[['price'],:]
corr_cols = list(corr.columns)
corr_cols.remove('price')
corr = corr[corr_cols]

# %%
# General Information
genInfo = corr.iloc[:,0:7]
sns.heatmap(genInfo.sort_values(by='price', axis = 1, ascending = False).T, annot=True)

# %%
# Most Popular Residence
comm = corr.iloc[:,7:24]
sns.heatmap(comm.sort_values(by='price', axis = 1, ascending = False).T, annot=True)

# %%
housing = corr.iloc[:,24:40]
sns.heatmap(housing.sort_values(by='price', axis = 1, ascending = False).T, annot=True)

# %%
style = corr.iloc[:,40:43]
sns.heatmap(style.sort_values(by='price', axis = 1, ascending = False).T, annot = True)

# %%
bed = corr.iloc[:,43:48]
sns.heatmap(bed.sort_values(by='price', axis = 1, ascending = False).T, annot = True)

# %%
cancellation = corr.iloc[:,48:51]
sns.heatmap(cancellation.sort_values(by='price', axis = 1, ascending = False).T, annot = True)

# %%
ameneties = corr.iloc[:,51:]
sns.heatmap(ameneties.sort_values(by='price', axis = 1, ascending = False).T)

# %%
distanceVecs = corr[['d_airport','d_downtown','d_pikeplace','d_amazon']]
distanceVecs.head()
sns.heatmap(distanceVecs.sort_values(by='price', axis = 1, ascending = False).T)

# %% [markdown]
# # KMeans Stuff

# %%
kmeansDistanceVecs = df[['d_airport','d_downtown','d_pikeplace','d_amazon', 'price']]
kmeansDistanceVecsTemp = (kmeansDistanceVecs ** 2)
kmeansDistanceVecs['tot'] = kmeansDistanceVecsTemp.sum(axis = 1).apply(np.sqrt)
kmeansDistanceVecs.head()
# Out:
# C:\Users\Arjun Mittal\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    d_airport  d_downtown  d_pikeplace  d_amazon     price       tot
# 0   0.567750    0.301354     0.260323  0.306945  0.066327  0.761273
# 1   0.576957    0.303310     0.263846  0.307148  0.132653  0.778734
# 2   0.537412    0.257394     0.214225  0.264340  0.974490  1.191831
# 3   0.576340    0.309527     0.269400  0.314284  0.081633  0.778453
# 4   0.553728    0.286280     0.244221  0.292985  0.438776  0.852396

# %%
# Group similar results together
kMeansAirport = kmeansDistanceVecs[['d_airport', 'price']]
npKMeansAirport = kMeansAirport.values
plt.scatter(npKMeansAirport[:,0],npKMeansAirport[:,1], label='True Position')

# %%
kMeansDowntown = kmeansDistanceVecs[['d_downtown', 'price']]
npKMeansDowntown = kMeansDowntown.values
plt.scatter(npKMeansDowntown[:,0],npKMeansDowntown[:,1])

# %%
kMeansPikeplace = kmeansDistanceVecs[['d_pikeplace', 'price']]
npKMeansPikeplace = kMeansPikeplace.values
plt.scatter(npKMeansPikeplace[:,0],npKMeansPikeplace[:,1])

# %%
kMeansAmazon = kmeansDistanceVecs[['d_amazon', 'price']]
npKMeansAmazon = kMeansAmazon.values
plt.scatter(npKMeansAmazon[:,0],npKMeansAmazon[:,1])

# %%
kMeanstot = kmeansDistanceVecs[['tot', 'price']]
npKMeanstot = kMeanstot.values
plt.scatter(npKMeanstot[:,0],npKMeanstot[:,1])

# %%
kmeans = KMeans(n_clusters=3)  
kmeans.fit(npKMeansAirport)  
plt.scatter(npKMeansAirport[:,0],npKMeansAirport[:,1], c=kmeans.labels_, cmap='rainbow')

# %%
kmeans2 = KMeans(n_clusters=3)  
kmeans2.fit(npKMeansDowntown)  
plt.scatter(npKMeansDowntown[:,0],npKMeansDowntown[:,1], c=kmeans2.labels_, cmap='rainbow')

# %%
kmeans3 = KMeans(n_clusters=3)  
kmeans3.fit(npKMeansPikeplace)  
plt.scatter(npKMeansPikeplace[:,0],npKMeansPikeplace[:,1], c=kmeans3.labels_, cmap='rainbow')

# %%
kmeans4 = KMeans(n_clusters=3)  
kmeans4.fit(npKMeansAmazon)  
plt.scatter(npKMeansAmazon[:,0],npKMeansAmazon[:,1], c=kmeans4.labels_, cmap='rainbow')

# %%
kmeans5 = KMeans(n_clusters=3)  
kmeans5.fit(npKMeanstot)  
plt.scatter(npKMeanstot[:,0],npKMeanstot[:,1], c=kmeans5.labels_, cmap='rainbow')

# %% [markdown]
# # Gaussian Mixture Models

# %%
gmm = GaussianMixture(n_components=3)
gmm.fit(npKMeansAirport)
X, Y = np.meshgrid(np.linspace(0, 1), np.linspace(0,1))
XX = np.array([X.ravel(), Y.ravel()]).T
Z = gmm.score_samples(XX)
Z = Z.reshape((50,50))
plt.contour(X, Y, Z)
plt.scatter(npKMeansAirport[:, 0], npKMeansAirport[:, 1])
plt.show()

# %%
gmm = GaussianMixture(n_components=3)
gmm.fit(npKMeansDowntown)
X, Y = np.meshgrid(np.linspace(0, 1), np.linspace(0,1))
XX = np.array([X.ravel(), Y.ravel()]).T
Z = gmm.score_samples(XX)
Z = Z.reshape((50,50))
plt.contour(X, Y, Z)
plt.scatter(npKMeansDowntown[:, 0], npKMeansDowntown[:, 1])
plt.show()

# %%
gmm = GaussianMixture(n_components=3)
gmm.fit(npKMeansPikeplace)
X, Y = np.meshgrid(np.linspace(0, 1), np.linspace(0,1))
XX = np.array([X.ravel(), Y.ravel()]).T
Z = gmm.score_samples(XX)
Z = Z.reshape((50,50))
plt.contour(X, Y, Z)
plt.scatter(npKMeansPikeplace[:, 0], npKMeansPikeplace[:, 1])
plt.show()

# %%
gmm = GaussianMixture(n_components=3)
gmm.fit(npKMeansAmazon)
X, Y = np.meshgrid(np.linspace(0, 1), np.linspace(0,1))
XX = np.array([X.ravel(), Y.ravel()]).T
Z = gmm.score_samples(XX)
Z = Z.reshape((50,50))
plt.contour(X, Y, Z)
plt.scatter(npKMeansAmazon[:, 0], npKMeansAmazon[:, 1])
plt.show()
